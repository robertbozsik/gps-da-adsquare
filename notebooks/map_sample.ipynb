# %% [markdown]
# ### imports

# %%
# imports
import pickle
import pandas as pd
import geopandas as gpd
import folium
# Out:
# /Users/robertbozsik/techtest/adsquare/adsquare_env/lib/python3.8/site-packages/geopandas/_compat.py:106: UserWarning: The Shapely GEOS version (3.8.0-CAPI-1.13.1 ) is incompatible with the GEOS version PyGEOS was compiled with (3.9.0-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(

# %% [markdown]
# # 3-4. Visualize the GPS signals of users and stores

# %%
stores_gdf = pd.read_pickle("../out_data_sample/stores_gdf.pkl")

# %%
stores_gdf.shape
# Out:
# (247, 3)

# %%
stores_gdf.head()
# Out:
#   store_id  store_name                                           geometry
# 0  place_1  McDonald's  POLYGON ((13.46119 52.47099, 13.46103 52.47066...
# 1  place_2  McDonald's  POLYGON ((13.46835 52.54716, 13.46841 52.54716...
# 2  place_3  McDonald's  POLYGON ((13.31288 52.41979, 13.31303 52.41966...
# 3  place_4  McDonald's  POLYGON ((13.36358 52.56060, 13.36358 52.56061...
# 4  place_5  McDonald's  POLYGON ((13.32309 52.56135, 13.32307 52.56128...

# %%
# open final_df
users_in_stores = pd.read_csv("../out_data_sample/users_in_stores.csv")

# %%
users_in_stores.shape
# Out:
# (2747, 6)

# %%
users_in_stores.head()
# Out:
#    device_id        lat        lon        date   store_id store_name
# 0      41282  52.485340  13.368210  2021-01-01  place_238    Renault
# 1      78319  52.485390  13.368412  2021-01-05  place_238    Renault
# 2      78319  52.485324  13.368606  2021-01-11  place_238    Renault
# 3      78319  52.485392  13.368405  2021-01-18  place_238    Renault
# 4      78319  52.485362  13.368547  2021-01-19  place_238    Renault

# %%
# create a map of Berlin
map_berlin = folium.Map(location=[52.5200,13.4050], zoom_start=11, tiles='cartodbpositron')

# display polygons of stores
stores_gdf.crs = "EPSG:4326" # Coordinate Reference System
folium.GeoJson(stores_gdf, 
               tooltip=folium.features.GeoJsonTooltip(
                   fields=['store_name'],
                   aliases=['store name:'])
              ).add_to(map_berlin);

# display latitudes and longitudes of device ids
for lat, lng, device_id, store_name, store_id in zip(users_in_stores["lat"], users_in_stores["lon"], users_in_stores["device_id"], users_in_stores["store_name"], users_in_stores["store_id"]):
    tooltip = f"user: {device_id}, store id: {store_id}"
    folium.CircleMarker(location=[lat, lng], 
                        radius=3, 
                        tooltip=tooltip, 
                        color="green",
                        fill=True, 
                        fill_color="green", 
                        fill_opacity=1
                       ).add_to(map_berlin)

# %%
# %time display(map_berlin)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
